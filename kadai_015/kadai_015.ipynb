# %%
class Human:
    def __init__(self, name, age):
      # 属性を定義する
      self.name = name
      self.age = age

    # メソッドを定義する
    def printinfo(self):
      print(f"名前:{self.name} 年齢:{self.age}才")

# インスタンス化する
human = Human("山田花子", 28)

human.printinfo()
# Out:
# 名前:山田花子 年齢:28才
